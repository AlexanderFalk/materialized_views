# %% [markdown]
# # Materialized Joins
#
# #### Author: Alexander Falk
# #### Date: 18-03-2018
# #### Type: Assignment
# #### Language: SQL
# #### Course: Database By Developers
#
#
# ## Question 1: Table Circuits report
#
# ###### What type of indices exists for the table and why they are of that type (and not some other type)

# %%
# %load_ext sql

# %%
# %sql postgresql://appdev@data:5432/appdev
# Out:
# 'Connected: appdev@appdev'

# %%
# %%sql select *
# from pg_indexes
# where tablename = 'circuits';
# Out:
# 3 rows affected.
# [('f1db', 'circuits', 'idx_17102_url', None, 'CREATE UNIQUE INDEX idx_17102_url ON circuits USING btree (url)'),
#  ('f1db', 'circuits', 'circuits_position_idx', None, 'CREATE INDEX circuits_position_idx ON circuits USING gist ("position")'),
#  ('f1db', 'circuits', 'idx_17102_primary', None, 'CREATE UNIQUE INDEX idx_17102_primary ON circuits USING btree (circuitid)')]

# %% [markdown]
# There exists three types of indices on the Circuits table.
# 1. The first one is a BTREE index, which is indexed on the URL. I believe it has been indexed on the URL due to the consistency in the beginning of each URL. They are all starting with http://en.wikipedia.org/wiki/, and then it can sorts of what is coming next in the URL. And it can index it on the alphabet.
# 2. The second has been using the GiST index type, which is very good when it comes to coordinates. GiST indexes are also capable of optimizing "nearest-neighbor" searches, which is suitable in our case with positions.
# 3. The third and last also uses BTREE, which is an obvious choice, when it comes to ID's. BTREEs will index on comparison between ID´s with the following operators: <, >, <=, >=, =.

# %% [markdown]
# ###### The amount of space each index takes up
#
# Below is the three Indexes and their sizes
#
# ###### Index size of 'idx_17102_url

# %%
# %sql select pg_size_pretty(pg_relation_size('idx_17102_url'));
# Out:
# 1 rows affected.
# [('16 kB',)]

# %% [markdown]
# ###### Index size of 'circuits_position_idx'

# %%
# %sql select pg_size_pretty(pg_relation_size('circuits_position_idx'));
# Out:
# 1 rows affected.
# [('8192 bytes',)]

# %% [markdown]
# ###### Index size of 'idx_17102_primary'

# %%
# %sql select pg_size_pretty(pg_relation_size('idx_17102_primary'));
# Out:
# 1 rows affected.
# [('16 kB',)]

# %% [markdown]
# ## Question 2: Winner of all races
#
# ###### We are talent scouts looking to win over some of the best new drivers there are. But we don't want them too old! Write a query that finds the winner of all the races, but only if they are younger than 38 years. The query should give return the date, driver surname, driver age, track time in milliseconds, race name and circuit name for all races.

# %%
# %%sql
# SELECT DISTINCT drivers.driverref, drivers.surname, drivers.dob, results.milliseconds, races.name, races.date, circuits.name from f1db.drivers
# INNER JOIN f1db.results ON drivers.driverid = results.driverid
# INNER JOIN f1db.races ON results.raceid = races.raceid
# INNER JOIN f1db.circuits ON races.circuitid = circuits.circuitid
# WHERE dob > '1980-01-01' AND positionorder = 1;
# Out:
# 199 rows affected.
# [('alonso', 'Alonso', datetime.date(1981, 7, 29), 4584572, 'Italian Grand Prix', datetime.date(2010, 9, 12), 'Autodromo Nazionale di Monza'),
#  ('alonso', 'Alonso', datetime.date(1981, 7, 29), 4717806, 'Italian Grand Prix', datetime.date(2007, 9, 9), 'Autodromo Nazionale di Monza'),
#  ('alonso', 'Alonso', datetime.date(1981, 7, 29), 5032413, 'Japanese Grand Prix', datetime.date(2006, 10, 8), 'Suzuka Circuit'),
#  ('alonso', 'Alonso', datetime.date(1981, 7, 29), 5151927, 'British Grand Prix', datetime.date(2006, 6, 11), 'Silverstone Circuit'),
#  ('alonso', 'Alonso', datetime.date(1981, 7, 29), 5181759, 'Spanish Grand Prix', datetime.date(2006, 5, 14), 'Circuit de Barcelona-Catalunya'),
#  ('alonso', 'Alonso', datetime.date(1981, 7, 29), 5188599, 'German Grand Prix', datetime.date(2005, 7, 24), 'Hockenheimring'),
#  ('alonso', 'Alonso', datetime.date(1981, 7, 29), 5258864, 'German Grand Prix', datetime.date(2010, 7, 25), 'Hockenheimring'),
#  ('alonso', 'Alonso', datetime.date(1981, 7, 29), 5261921, 'San Marino Grand Prix', datetime.date(2005, 4, 24), 'Autodromo Enzo e Dino Ferrari'),
#  ('alonso', 'Alonso', datetime.date(1981, 7, 29), 5321196, 'British Grand Prix', datetime.date(2011, 7, 10), 'Silverstone Circuit'),
#  ('alonso', 'Alonso', datetime.date(1981, 7, 29), 5358531, 'Bahrain Grand Prix', datetime.date(2005, 4, 3), 'Bahrain International Circuit'),
#  ('alonso', 'Alonso', datetime.date(1981, 7, 29), 5386205, 'Bahrain Grand Prix', datetime.date(2006, 3, 12), 'Bahrain International Circuit'),
#  ('alonso', 'Alonso', datetime.date(1981, 7, 29), 5421892, 'Japanese Grand Prix', datetime.date(2008, 10, 12), 'Fuji Speedway'),
#  ('alonso', 'Alonso', datetime.date(1981, 7, 29), 5465862, 'German Grand Prix', datetime.date(2012, 7, 22), 'Hockenheimring'),
#  ('alonso', 'Alonso', datetime.date(1981, 7, 29), 5482232, 'French Grand Prix', datetime.date(2005, 7, 3), 'Circuit de Nevers Magny-Cours'),
#  ('alonso', 'Alonso', datetime.date(1981, 7, 29), 5493736, 'Malaysian Grand Prix', datetime.date(2005, 3, 20), 'Sepang International Circuit'),
#  ('alonso', 'Alonso', datetime.date(1981, 7, 29), 5506648, 'European Grand Prix', datetime.date(2005, 5, 29), 'Nürburgring'),
#  ('alonso', 'Alonso', datetime.date(1981, 7, 29), 5534930, 'Malaysian Grand Prix', datetime.date(2007, 4, 8), 'Sepang International Circuit'),
#  ('alonso', 'Alonso', datetime.date(1981, 7, 29), 5667870, 'Australian Grand Prix', datetime.date(2006, 4, 2), 'Albert Park Grand Prix Circuit'),
#  ('alonso', 'Alonso', datetime.date(1981, 7, 29), 5677308, 'Canadian Grand Prix', datetime.date(2006, 6, 25), 'Circuit Gilles Villeneuve'),
#  ('alonso', 'Alonso', datetime.date(1981, 7, 29), 5786945, 'Chinese Grand Prix', datetime.date(2013, 4, 14), 'Shanghai International Circuit'),
#  ('alonso', 'Alonso', datetime.date(1981, 7, 29), 5941460, 'Hungarian Grand Prix', datetime.date(2003, 8, 24), 'Hungaroring'),
#  ('alonso', 'Alonso', datetime.date(1981, 7, 29), 5956596, 'Spanish Grand Prix', datetime.date(2013, 5, 12), 'Circuit de Barcelona-Catalunya'),
#  ('alonso', 'Alonso', datetime.date(1981, 7, 29), 5960396, 'Bahrain Grand Prix', datetime.date(2010, 3, 14), 'Bahrain International Circuit'),
#  ('alonso', 'Alonso', datetime.date(1981, 7, 29), 5993618, 'Chinese Grand Prix', datetime.date(2005, 10, 16), 'Shanghai International Circuit'),
#  ('alonso', 'Alonso', datetime.date(1981, 7, 29), 6029329, 'Monaco Grand Prix', datetime.date(2007, 5, 27), 'Circuit de Monaco'),
#  ('alonso', 'Alonso', datetime.date(1981, 7, 29), 6223116, 'Monaco Grand Prix', datetime.date(2006, 5, 28), 'Circuit de Monaco'),
#  ('alonso', 'Alonso', datetime.date(1981, 7, 29), 6256649, 'European Grand Prix', datetime.date(2012, 6, 24), 'Valencia Street Circuit'),
#  ('alonso', 'Alonso', datetime.date(1981, 7, 29), 7036304, 'Singapore Grand Prix', datetime.date(2008, 9, 28), 'Marina Bay Street Circuit'),
#  ('alonso', 'Alonso', datetime.date(1981, 7, 29), 7073579, 'Singapore Grand Prix', datetime.date(2010, 9, 26), 'Marina Bay Street Circuit'),
#  ('alonso', 'Alonso', datetime.date(1981, 7, 29), 7586358, 'European Grand Prix', datetime.date(2007, 7, 22), 'Nürburgring'),
#  ('alonso', 'Alonso', datetime.date(1981, 7, 29), 9891812, 'Malaysian Grand Prix', datetime.date(2012, 3, 25), 'Sepang International Circuit'),
#  ('alonso', 'Alonso', datetime.date(1981, 7, 29), 10100810, 'Korean Grand Prix', datetime.date(2010, 10, 24), 'Korean International Circuit'),
#  ('bottas', 'Bottas', datetime.date(1989, 8, 28), 4908523, 'Austrian Grand Prix', datetime.date(2017, 7, 9), 'Red Bull Ring'),
#  ('bottas', 'Bottas', datetime.date(1989, 8, 28), 5288743, 'Russian Grand Prix', datetime.date(2017, 4, 30), 'Sochi Autodrom'),
#  ('button', 'Button', datetime.date(1980, 1, 19), 4252092, 'Malaysian Grand Prix', datetime.date(2009, 4, 5), 'Sepang International Circuit'),
#  ('button', 'Button', datetime.date(1980, 1, 19), 5184848, 'Turkish Grand Prix', datetime.date(2009, 6, 7), 'Istanbul Park'),
#  ('button', 'Button', datetime.date(1980, 1, 19), 5348530, 'Belgian Grand Prix', datetime.date(2012, 9, 2), 'Circuit de Spa-Francorchamps'),
#  ('button', 'Button', datetime.date(1980, 1, 19), 5453427, 'Japanese Grand Prix', datetime.date(2011, 10, 9), 'Suzuka Circuit'),
#  ('button', 'Button', datetime.date(1980, 1, 19), 5508182, 'Bahrain Grand Prix', datetime.date(2009, 4, 26), 'Bahrain International Circuit'),
#  ('button', 'Button', datetime.date(1980, 1, 19), 5616531, 'Australian Grand Prix', datetime.date(2010, 3, 28), 'Albert Park Grand Prix Circuit'),
#  ('button', 'Button', datetime.date(1980, 1, 19), 5649565, 'Australian Grand Prix', datetime.date(2012, 3, 18), 'Albert Park Grand Prix Circuit'),
#  ('button', 'Button', datetime.date(1980, 1, 19), 5655784, 'Australian Grand Prix', datetime.date(2009, 3, 29), 'Albert Park Grand Prix Circuit'),
#  ('button', 'Button', datetime.date(1980, 1, 19), 5839202, 'Spanish Grand Prix', datetime.date(2009, 5, 10), 'Circuit de Barcelona-Catalunya'),
#  ('button', 'Button', datetime.date(1980, 1, 19), 6044282, 'Monaco Grand Prix', datetime.date(2009, 5, 24), 'Circuit de Monaco'),
#  ('button', 'Button', datetime.date(1980, 1, 19), 6322656, 'Brazilian Grand Prix', datetime.date(2012, 11, 25), 'Autódromo José Carlos Pace'),
#  ('button', 'Button', datetime.date(1980, 1, 19), 6402163, 'Chinese Grand Prix', datetime.date(2010, 4, 18), 'Shanghai International Circuit'),
#  ('button', 'Button', datetime.date(1980, 1, 19), 6402337, 'Hungarian Grand Prix', datetime.date(2011, 7, 31), 'Hungaroring'),
#  ('button', 'Button', datetime.date(1980, 1, 19), 6740941, 'Hungarian Grand Prix', datetime.date(2006, 8, 6), 'Hungaroring'),
#  ('button', 'Button', datetime.date(1980, 1, 19), 14679537, 'Canadian Grand Prix', datetime.date(2011, 6, 12), 'Circuit Gilles Villeneuve'),
#  ('hamilton', 'Hamilton', datetime.date(1985, 1, 7), 4532312, 'Italian Grand Prix', datetime.date(2017, 9, 3), 'Autodromo Nazionale di Monza'),
#  ('hamilton', 'Hamilton', datetime.date(1985, 1, 7), 4680688, 'Italian Grand Prix', datetime.date(2015, 9, 6), 'Autodromo Nazionale di Monza'),
#  ('hamilton', 'Hamilton', datetime.date(1985, 1, 7), 4750236, 'Italian Grand Prix', datetime.date(2014, 9, 7), 'Autodromo Nazionale di Monza'),
#  ('hamilton', 'Hamilton', datetime.date(1985, 1, 7), 4781221, 'Italian Grand Prix', datetime.date(2012, 9, 9), 'Autodromo Nazionale di Monza'),
#  ('hamilton', 'Hamilton', datetime.date(1985, 1, 7), 4887430, 'British Grand Prix', datetime.date(2017, 7, 16), 'Silverstone Circuit'),
#  ('hamilton', 'Hamilton', datetime.date(1985, 1, 7), 5020387, 'Belgian Grand Prix', datetime.date(2015, 8, 23), 'Circuit de Spa-Francorchamps'),
#  ('hamilton', 'Hamilton', datetime.date(1985, 1, 7), 5082820, 'Belgian Grand Prix', datetime.date(2017, 8, 27), 'Circuit de Spa-Francorchamps'),
#  ('hamilton', 'Hamilton', datetime.date(1985, 1, 7), 5258107, 'Austrian Grand Prix', datetime.date(2016, 7, 3), 'Red Bull Ring'),
#  ('hamilton', 'Hamilton', datetime.date(1985, 1, 7), 5327620, 'Turkish Grand Prix', datetime.date(2010, 5, 30), 'Istanbul Park'),
#  ('hamilton', 'Hamilton', datetime.date(1985, 1, 7), 5344268, 'Belgian Grand Prix', datetime.date(2010, 8, 29), 'Circuit de Spa-Francorchamps'),
#  ('hamilton', 'Hamilton', datetime.date(1985, 1, 7), 5444200, 'German Grand Prix', datetime.date(2016, 7, 31), 'Hockenheimring'),
#  ('hamilton', 'Hamilton', datetime.date(1985, 1, 7), 5465296, 'Canadian Grand Prix', datetime.date(2016, 6, 12), 'Circuit Gilles Villeneuve'),
#  ('hamilton', 'Hamilton', datetime.date(1985, 1, 7), 
),
#  ('hamilton', 'Hamilton', datetime.date(1985, 1, 7), 6149445, 'Hungarian Grand Prix', datetime.date(2013, 7, 28), 'Hungaroring'),
#  ('hamilton', 'Hamilton', datetime.date(1985, 1, 7), 6251292, 'Canadian Grand Prix', datetime.date(2007, 6, 10), 'Circuit Gilles Villeneuve'),
#  ('hamilton', 'Hamilton', datetime.date(1985, 1, 7), 6652703, 'United States Grand Prix', datetime.date(2015, 10, 25), 'Circuit of the Americas'),
#  ('hamilton', 'Hamilton', datetime.date(1985, 1, 7), 6703021, 'Japanese Grand Prix', datetime.date(2014, 10, 5), 'Suzuka Circuit'),
#  ('hamilton', 'Hamilton', datetime.date(1985, 1, 7), 6966337, 'Singapore Grand Prix', datetime.date(2009, 9, 27), 'Marina Bay Street Circuit'),
#  ('hamilton', 'Hamilton', datetime.date(1985, 1, 7), 7169133, 'Monaco Grand Prix', datetime.date(2016, 5, 29), 'Circuit de Monaco'),
#  ('hamilton', 'Hamilton', datetime.date(1985, 1, 7), 7204795, 'Singapore Grand Prix', datetime.date(2014, 9, 21), 'Marina Bay Street Circuit'),
#  ('hamilton', 'Hamilton', datetime.date(1985, 1, 7), 7234579, 'Japanese Grand Prix', datetime.date(2007, 9, 30), 'Fuji Speedway'),
#  ('hamilton', 'Hamilton', datetime.date(1985, 1, 7), 7242742, 'Monaco Grand Prix', datetime.date(2008, 5, 25), 'Circuit de Monaco'),
#  ('hamilton', 'Hamilton', datetime.date(1985, 1, 7), 7403544, 'Singapore Grand Prix', datetime.date(2017, 9, 17), 'Marina Bay Street Circuit'),
#  ('hamilton', 'Hamilton', datetime.date(1985, 1, 7), 8812094, 'British Grand Prix', datetime.date(2014, 7, 6), 'Silverstone Circuit'),
#  ('hamilton', 'Hamilton', datetime.date(1985, 1, 7), 10861335, 'Brazilian Grand Prix', datetime.date(2016, 11, 13), 'Autódromo José Carlos Pace'),
#  ('hamilton', 'Hamilton', datetime.date(1985, 1, 7), None, 'Japanese Grand Prix', datetime.date(2015, 9, 27), 'Suzuka Circuit'),
#  ('kovalainen', 'Kovalainen', datetime.date(1981, 10, 19), 5847067, 'Hungarian Grand Prix', datetime.date(2008, 8, 3), 'Hungaroring'),
#  ('kubica', 'Kubica', datetime.date(1984, 12, 7), 5784227, 'Canadian Grand Prix', datetime.date(2008, 6, 8), 'Circuit Gilles Villeneuve'),
#  ('maldonado', 'Maldonado', datetime.date(1985, 3, 9), 5949145, 'Spanish Grand Prix', datetime.date(2012, 5, 13), 'Circuit de Barcelona-Catalunya'),
#  ('massa', 'Massa', datetime.date(1981, 4, 25), 4979394, 'Belgian Grand Prix', datetime.date(2008, 9, 7), 'Circuit de Spa-Francorchamps'),
#  ('massa', 'Massa', datetime.date(1981, 4, 25), 5202161, 'Turkish Grand Prix', datetime.date(2007, 8, 26), 'Istanbul Park'),
#  ('massa', 'Massa', datetime.date(1981, 4, 25), 5209451, 'Turkish Grand Prix', datetime.date(2008, 5, 11), 'Istanbul Park'),
#  ('massa', 'Massa', datetime.date(1981, 4, 25), 5331082, 'Turkish Grand Prix', datetime.date(2006, 8, 27), 'Istanbul Park'),
#  ('massa', 'Massa', datetime.date(1981, 4, 25), 5466970, 'Bahrain Grand Prix', datetime.date(2008, 4, 6), 'Bahrain International Circuit'),
#  ('massa', 'Massa', datetime.date(1981, 4, 25), 5496230, 'Spanish Grand Prix', datetime.date(2007, 5, 13), 'Circuit de Barcelona-Catalunya'),
#  ('massa', 'Massa', datetime.date(1981, 4, 25), 5510245, 'French Grand Prix', datetime.date(2008, 6, 22), 'Circuit de Nevers Magny-Cours'),
#  ('massa', 'Massa', datetime.date(1981, 4, 25), 5513751, 'Brazilian Grand Prix', datetime.date(2006, 10, 22), 'Autódromo José Carlos Pace'),
#  ('massa', 'Massa', datetime.date(1981, 4, 25), 5607515, 'Bahrain Grand Prix', datetime.date(2007, 4, 15), 'Bahrain International Circuit'),
#  ('massa', 'Massa', datetime.date(1981, 4, 25), 5651435, 'Brazilian Grand Prix', datetime.date(2008, 11, 2), 'Autódromo José Carlos Pace'),
#  ('massa', 'Massa', datetime.date(1981, 4, 25), 5732339, 'European Grand Prix', datetime.date(2008, 8, 24), 'Valencia Street Circuit'),
#  ('max_verstappen', 'Verstappen', datetime.date(1997, 9, 30), 5401290, 'Malaysian Grand Prix', datetime.date(2017, 10, 1), 'Sepang International Circuit'),
#  ('max_verstappen', 'Verstappen', datetime.date(1997, 9, 30), 6100017, 'Spanish Grand Prix', datetime.date(2016, 5, 15), 'Circuit de Barcelona-Catalunya'),
#  ('ricciardo', 'Ricciardo', datetime.date(1989, 7, 1), 5076556, 'Belgian Grand Prix', datetime.date(2014, 8, 24), 'Circuit de Spa-Francorchamps'),
#  ('ricciardo', 'Ricciardo', datetime.date(1989, 7, 1), 5832776, 'Malaysian Grand Prix', datetime.date(2016, 10, 2), 'Sepang International Circuit'),
#  ('ricciardo', 'Ricciardo', datetime.date(1989, 7, 1), 5952830, 'Canadian Grand Prix', datetime.date(2014, 6, 8), 'Circuit Gilles Villeneuve'),
#  ('ricciardo', 'Ricciardo', datetime.date(1989, 7, 1), 6785058, 'Hungarian Grand Prix', datetime.date(2014, 7, 27), 'Hungaroring'),
#  ('ricciardo', 'Ricciardo', datetime.date(1989, 7, 1), 7435573, 'Azerbaijan Grand Prix', datetime.date(2017, 6, 25), 'Baku City Circuit'),
#  ('rosberg', 'Rosberg', datetime.date(1985, 6, 27), 4648089, 'Italian Grand Prix', datetime.date(2016, 9, 4), 'Autodromo Nazionale di Monza'),
#  ('rosberg', 'Rosberg', datetime.date(1985, 6, 27), 5203333, 'Japanese Grand Prix', datetime.date(2016, 10, 9), 'Suzuka Circuit'),
#  ('rosberg', 'Rosberg', datetime.date(1985, 6, 27), 5274976, 'Austrian Grand Prix', datetime.date(2014, 6, 22), 'Red Bull Ring'),
#  ('rosberg', 'Rosberg', datetime.date(1985, 6, 27), 5402555, 'Brazilian Grand Prix', datetime.date(2014, 11, 9), 'Autódromo José Carlos Pace'),
#  ('rosberg', 'Rosberg', datetime.date(1985, 6, 27), 5416930, 'Austrian Grand Prix', datetime.date(2015, 6, 21), 'Red Bull Ring'),
#  ('rosberg', 'Rosberg', datetime.date(1985, 6, 27), 5469090, 'Brazilian Grand Prix', datetime.date(2015, 11, 15), 'Autódromo José Carlos Pace'),
#  ('rosberg', 'Rosberg', datetime.date(1985, 6, 27), 5561997, 'Russian Grand Prix', datetime.date(2016, 5, 1), 'Sochi Autodrom'),
#  ('rosberg', 'Rosberg', datetime.date(1985, 6, 27), 5572366, 'European Grand Prix', datetime.date(2016, 6, 19), 'Baku City Circuit'),
#  ('rosberg', 'Rosberg', datetime.date(1985, 6, 27), 5578710, 'Australian Grand Prix', datetime.date(2014, 3, 16), 'Albert Park Grand Prix Circuit'),
#  ('rosberg', 'Rosberg', datetime.date(1985, 6, 27), 5579456, 'British Grand Prix', datetime.date(2013, 6, 30), 'Silverstone Circuit'),
#  ('rosberg', 'Rosberg', datetime.date(1985, 6, 27), 5614696, 'Bahrain Grand Prix', datetime.date(2016, 4, 3), 'Bahrain International Circuit'),
#  ('rosberg', 'Rosberg', datetime.date(1985, 6, 27), 5622914, 'German Grand Prix', datetime.date(2014, 7, 20), 'Hockenheimring'),
#  ('rosberg', 'Rosberg', datetime.date(1985, 6, 27), 5786929, 'Chinese Grand Prix', datetime.date(2012, 4, 15), 'Shanghai International Circuit'),
#  ('rosberg', 'Rosberg', datetime.date(1985, 6, 27), 5910175, 'Abu Dhabi Grand Prix', datetime.date(2015, 11, 29), 'Yas Marina Circuit'),
#  ('rosberg', 'Rosberg', datetime.date(1985, 6, 27), 5933891, 'Chinese Grand Prix', datetime.date(2016, 4, 17), 'Shanghai International Circuit'),
#  ('rosberg', 'Rosberg', datetime.date(1985, 6, 27), 6072555, 'Spanish Grand Prix', datetime.date(2015, 5, 10), 'Circuit de Barcelona-Catalunya'),
#  ('rosberg', 'Rosberg', datetime.date(1985, 6, 27), 6155038, 'Mexican Grand Prix', datetime.date(2015, 11, 1), 'Autódromo Hermanos Rodríguez'),
#  ('rosberg', 'Rosberg', datetime.date(1985, 6, 27), 6291058, 'Belgian Grand Prix', datetime.date(2016, 8, 28), 'Circuit de Spa-Francorchamps'),
#  ('rosberg', 'Rosberg', datetime.date(1985, 6, 27),
circuit'),
#  ('vettel', 'Vettel', datetime.date(1987, 7, 3), 5943301, 'Spanish Grand Prix', datetime.date(2011, 5, 22), 'Circuit de Barcelona-Catalunya'),
#  ('vettel', 'Vettel', datetime.date(1987, 7, 3), 5957148, 'United States Grand Prix', datetime.date(2013, 11, 17), 'Circuit of the Americas'),
#  ('vettel', 'Vettel', datetime.date(1987, 7, 3), 5976169, 'European Grand Prix', datetime.date(2011, 6, 26), 'Valencia Street Circuit'),
#  ('vettel', 'Vettel', datetime.date(1987, 7, 3), 5976837, 'Abu Dhabi Grand Prix', datetime.date(2010, 11, 14), 'Yas Marina Circuit'),
#  ('vettel', 'Vettel', datetime.date(1987, 7, 3), 5986713, 'Hungarian Grand Prix', datetime.date(2017, 7, 30), 'Hungaroring'),
#  ('vettel', 'Vettel', datetime.date(1987, 7, 3), 6029571, 'European Grand Prix', datetime.date(2010, 6, 27), 'Valencia Street Circuit'),
#  ('vettel', 'Vettel', datetime.date(1987, 7, 3), 6065793, 'Malaysian Grand Prix', datetime.date(2015, 3, 29), 'Sepang International Circuit'),
#  ('vettel', 'Vettel', datetime.date(1987, 7, 3), 6074711, 'German Grand Prix', datetime.date(2013, 7, 7), 'Nürburgring'),
#  ('vettel', 'Vettel', datetime.date(1987, 7, 3), 6193701, 'Korean Grand Prix', datetime.date(2013, 10, 6), 'Korean International Circuit'),
#  ('vettel', 'Vettel', datetime.date(1987, 7, 3), 6284340, 'Monaco Grand Prix', datetime.date(2017, 5, 28), 'Circuit de Monaco'),
#  ('vettel', 'Vettel', datetime.date(1987, 7, 3), 6369985, 'Hungarian Grand Prix', datetime.date(2015, 7, 26), 'Hungaroring'),
#  ('vettel', 'Vettel', datetime.date(1987, 7, 3), 7063485, 'Chinese Grand Prix', datetime.date(2009, 4, 19), 'Shanghai International Circuit'),
#  ('vettel', 'Vettel', datetime.date(1987, 7, 3), 7146757, 'Singapore Grand Prix', datetime.date(2011, 9, 25), 'Marina Bay Street Circuit'),
#  ('vettel', 'Vettel', datetime.date(1987, 7, 3), 7153132, 'Singapore Grand Prix', datetime.date(2013, 9, 22), 'Marina Bay Street Circuit'),
#  ('vettel', 'Vettel', datetime.date(1987, 7, 3), 7226144, 'Singapore Grand Prix', datetime.date(2012, 9, 23), 'Marina Bay Street Circuit'),
#  ('vettel', 'Vettel', datetime.date(1987, 7, 3), 7282118, 'Singapore Grand Prix', datetime.date(2015, 9, 20), 'Marina Bay Street Circuit'),
#  ('vettel', 'Vettel', datetime.date(1987, 7, 3), 7778373, 'Monaco Grand Prix', datetime.date(2011, 5, 29), 'Circuit de Monaco')]

# %% [markdown]
# ## Question 3 - Describe the query using EXPLAIN ANALYZE with at least 5 lines of text. Answer at least the following:
#
# ###### How many calls are you making?
# ###### How long does it take to perform the query?

# %% [markdown]
# #### Answer

# %%
# %%sql EXPLAIN ANALYZE SELECT DISTINCT drivers.driverref, drivers.surname, drivers.dob, results.milliseconds, races.name, races.date, circuits.name from f1db.drivers
# INNER JOIN f1db.results ON drivers.driverid = results.driverid
# INNER JOIN f1db.races ON results.raceid = races.raceid
# INNER JOIN f1db.circuits ON races.circuitid = circuits.circuitid
# WHERE dob > '1980-01-01' AND positionorder = 1;
# Out:
# 22 rows affected.
# [('Unique  (cost=787.46..788.84 rows=69 width=70) (actual time=11.161..11.851 rows=199 loops=1)',),
#  ('  ->  Sort  (cost=787.46..787.63 rows=69 width=70) (actual time=11.159..11.372 rows=199 loops=1)',),
#  ('        Sort Key: drivers.driverref, drivers.surname, drivers.dob, results.milliseconds, races.name, races.date, circuits.name',),
#  ('        Sort Method: quicksort  Memory: 52kB',),
#  ('        ->  Nested Loop  (cost=25.68..785.35 rows=69 width=70) (actual time=0.454..10.485 rows=199 loops=1)',),
#  ('              ->  Nested Loop  (cost=25.54..773.21 rows=69 width=58) (actual time=0.442..8.770 rows=199 loops=1)',),
#  ('                    ->  Hash Join  (cost=25.26..746.51 rows=69 width=35) (actual time=0.420..7.509 rows=199 loops=1)',),
#  ('                          Hash Cond: (results.driverid = drivers.driverid)',),
#  ('                          ->  Seq Scan on results  (cost=0.00..708.96 rows=974 width=24) (actual time=0.009..5.451 rows=974 loops=1)',),
#  ('                                Filter: (positionorder = 1)',),
#  ('                                Rows Removed by Filter: 22703',),
#  ('                          ->  Hash  (cost=24.51..24.51 rows=60 width=27) (actual time=0.398..0.398 rows=61 loops=1)',),
#  ('                                Buckets: 1024  Batches: 1  Memory Usage: 12kB',),
#  ('                                ->  Seq Scan on drivers  (cost=0.00..24.51 rows=60 width=27) (actual time=0.005..0.229 rows=61 loops=1)',),
#  ("                                      Filter: (dob > '1980-01-01'::date)",),
#  ('                                      Rows Removed by Filter: 780',),
#  ('                    ->  Index Scan using idx_17199_primary on races  (cost=0.28..0.39 rows=1 width=39) (actual time=0.003..0.003 rows=1 loops=199)',),
#  ('                          Index Cond: (raceid = results.raceid)',),
#  ('              ->  Index Scan using idx_17102_primary on circuits  (cost=0.14..0.18 rows=1 width=28) (actual time=0.002..0.002 rows=1 loops=199)',),
#  ('                    Index Cond: (circuitid = races.circuitid)',),
#  ('Planning time: 0.753 ms',),
#  ('Execution time: 12.133 ms',)]

# %% [markdown]
# The query takes about ~15ms and it makes around 20 calls throughout the query. It removes, seeks in indexed, do nested loops for the searching, joins, and sorts to create the correct result. It is a more "heavy" query and it could probably had been optimized. The first thing it does is sorting the whole thing with the keys defined in the select statement. It uses the quicksort sorting algorithm to sort the whole thing. The quicksort methods picks an element in the table as its pivot and sorts it on that. The pivots is set in each of the tables defined by the keys. Then it loops through the tables to find matches and then hash joins on the joins stated in the statement. The hashing gives the correct result for a match. Then it starts to sequential scan through each table to filter out everything that is not needed (it removes the rows) and doesn't match the search criterias. Lastly it index scans on the index conditions to figure out which results should be in the final table and then it prints it out.

# %% [markdown]
# ## Question 4 - Create a materialized view of your query. Using EXPLAIN ANALYZE try to query the view. Write at least 5 lines of text explaining what's going on and why the query execution time changed.

# %%
# %%sql CREATE MATERIALIZED VIEW race_winners_below_38 AS SELECT DISTINCT drivers.driverref, drivers.surname, drivers.dob, results.milliseconds, races.name AS racename, races.date, circuits.name AS circuitname from f1db.drivers
# INNER JOIN f1db.results ON drivers.driverid = results.driverid
# INNER JOIN f1db.races ON results.raceid = races.raceid
# INNER JOIN f1db.circuits ON races.circuitid = circuits.circuitid
# WHERE dob > '1980-01-01' AND positionorder = 1;
# Out:
# 199 rows affected.
# []

# %%
# %sql EXPLAIN ANALYZE  select * from race_winners_below_38;
# Out:
# 3 rows affected.
# [('Seq Scan on race_winners_below_38  (cost=0.00..10.30 rows=30 width=2080) (actual time=0.010..0.188 rows=199 loops=1)',),
#  ('Planning time: 0.109 ms',),
#  ('Execution time: 0.368 ms',)]

# %% [markdown]
# #### Answer

# %% [markdown]
# There are different ways of creating a view. When we just create a 'VIEW', we get a representation of a query. This can be a good thing, if we want the realtime data all the time. 'VIEWS' execute the query, it has been assigned, everytime it is being called. This can be a heavy task and this is where 'MATERIALIZED VIEWS' comes into the picture. 'MATERIALIZED VIEWS' are a representation of the exact moment the query, it has been assigned, was being executed - a static snapshot. After execution, the 'MATERIALIZED VIEW' will be cached, which means; we don't need to execute the query each time we need the view. We get the cached one - a state of the data from that time it was executed. If we want the data to be refreshed, we can just call the 'REFRESH' command on the materialzed view and then it will execute the query once again and then cache it.
